# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization import make_lupton_rgb
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
import matplotlib.pyplot as plt
from glob import glob
import os
import matplotlib.image as mpimg
from IPython import display
# %matplotlib inline

# %%
name1 = get_pkg_data_filename('479906/diff19500450.fits')
name2 = get_pkg_data_filename('479906/diff19514152.fits')

# %%
a1 = fits.open(name1)[0].data
a2 = fits.open(name2)[0].data

# %%
rgb_default = make_lupton_rgb(a1,a2, a2, filename="test1.jpeg")
plt.imshow(rgb_default, origin='lower')

# %%
rootdir = '.'
for subdir, dirs, files in os.walk(rootdir):
    print subdir
    tars = 0.0
    for tar in [f for f in files if f.endswith(".tar.gz")]:
        #print files
        tars +=1.0
    if tars >=3:
        print "yes"
        for f in files:
            #if diff.startswith('diff') in [diff for diff in f if f.endswith(".fits")]:
            diffs = []
            if f.startswith('diff'):
                if f.endswith('.fits'):
                    diffs.append(f)
                    print f
            print diffs
#             name1 = get_pkg_data_filename(subdir+'/'+diffs[0])
#             name2 = get_pkg_data_filename(subdir+'/'+diffs[1])
#             name3 = get_pkg_data_filename(subdir+'/'+diffs[2])
#             a1 = fits.open(name1)[0].data
#             a2 = fits.open(name2)[0].data
#             a3 = fits.open(name3)[0].data
#             rgb_default = make_lupton_rgb(a1,a2, a2)
#             plt.imshow(rgb_default, origin='lower')
# Out:
# .
# ./479906
# yes
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-ae1942abe552> in <module>()
#      16                     print f
#      17             print diffs
# ---> 18             name1 = get_pkg_data_filename(subdir+'/'+diffs[0])
#      19             name2 = get_pkg_data_filename(subdir+'/'+diffs[1])
#      20             name3 = get_pkg_data_filename(subdir+'/'+diffs[2])
#
# IndexError: list index out of range

# %%
snids = [479906,480122,479420,479601,479824,480031,480153,479680,479596,479812,480400]

# %%
difffits = {}
srchfits ={}
tmpfits = {}
for s in snids:
    difffits[s] = glob('./'+str(s)+'/diff*.fits')
    srchfits[s] = glob('./'+str(s)+'/srch*.fits')
    tmpfits[s] = glob('./'+str(s)+'/temp*.fits')

# %%
#difffits
fig, ax = plt.subplots(ncols=3, nrows=5, sharex=False, sharey=False, dpi=120, ) #figsize=(13, 5)
goods, goodt, goodf = [], [], []

for key, vals in srchfits.iteritems():
#    print key
    if len(vals) >=3:
        goods.append(vals)
for key, vals in tmpfits.iteritems():
#    print key
    if len(vals) >=3:
        goodt.append(vals)
for key, vals in difffits.iteritems():
#    print key
    if len(vals) >=3:
        goodf.append(vals)
for i in range(len(goods)):
    name1 = get_pkg_data_filename(goods[i][0])
    name2 = get_pkg_data_filename(goods[i][1])
    name3 = get_pkg_data_filename(goods[i][2])
    a1 = fits.open(name1)[0].data
    a2 = fits.open(name2)[0].data
    a3 = fits.open(name3)[0].data
    rgb_default = make_lupton_rgb(a1,a2, a2)
    ax[i,0].imshow(rgb_default, origin='lower')
    
for i in range(len(goodt)):
    name1 = get_pkg_data_filename(goodt[i][0])
    name2 = get_pkg_data_filename(goodt[i][1])
    name3 = get_pkg_data_filename(goodt[i][2])
    a1 = fits.open(name1)[0].data
    a2 = fits.open(name2)[0].data
    a3 = fits.open(name3)[0].data
    rgb_default = make_lupton_rgb(a1,a2, a2)
    ax[i,1].imshow(rgb_default, origin='lower')
    
for i in range(len(goodf)):
    name1 = get_pkg_data_filename(goodf[i][0])
    name2 = get_pkg_data_filename(goodf[i][1])
    name3 = get_pkg_data_filename(goodf[i][2])
    a1 = fits.open(name1)[0].data
    a2 = fits.open(name2)[0].data
    a3 = fits.open(name3)[0].data
    rgb_default = make_lupton_rgb(a1,a2, a2)
    ax[i,2].imshow(rgb_default, origin='lower')

# %%
namer = get_pkg_data_filename('479420/srch19438773.fits')
nameg = get_pkg_data_filename('479420/srch19510524.fits')
namez = get_pkg_data_filename('479420/srch19436627.fits')
r = fits.open(name1)[0].data
g = fits.open(name2)[0].data
z = fits.open(name3)[0].data
rgb_default = make_lupton_rgb(r,g,z, stretch=5, Q=8)
plt.imshow(rgb_default, origin='lower')

# %%
hdu_list = fits.open('479906/diff19514152.fits')
image_data = hdu_list[0].data
print(type(image_data))
print(image_data.shape)

plt.imshow(image_data, cmap='gray')
plt.colorbar()

# %%
img=mpimg.imread('479906/diff19514152.gif')
imgplot = plt.imshow(img)

# %%
from matplotlib.colors import LogNorm

# %%
hdu_list = fits.open('desgw190510c/srch_g.fits')
image_data = hdu_list[0].data
plt.imshow(image_data, cmap='gray')
plt.axis('off');
print('Min:', np.min(image_data))
print('Max:', np.max(image_data))
print('Mean:', np.mean(image_data))
print('Stdev:', np.std(image_data))
# Out:
# ('Min:', -86.04669)
# ('Max:', 154.82184)
# ('Mean:', 6.172388)
# ('Stdev:', 31.246294)

# %%
fig, ax = plt.subplots(ncols=11, nrows=3, sharex=True, sharey=True, dpi=120, figsize=(15,5))
fig.subplots_adjust(hspace=0)

srch_list = [g for g in glob('desgw*/srch*.fits')]
temp_list = [g for g in glob('desgw*/temp*.fits')]
diff_list = [g for g in glob('desgw*/diff*.fits')]

cands = ['desgw190510a', 'desgw190510b', 'desgw190510c', 'desgw190510d', 'desgw190510e', 'desgw190510f','desgw190510g', 'desgw190510h', 'desgw190510i','desgw190510j', 'desgw190510k']
for i, cand in enumerate(cands):
    srch_image_list = filter(lambda x:cand in x, srch_list)
    temp_image_list = filter(lambda x:cand in x, temp_list)
    diff_image_list = filter(lambda x:cand in x, diff_list)#make list of just desgw190510*/ dir
    
    srch_image_concat = []
    temp_image_concat = []
    diff_image_concat = []
    
    #combine images 
    for image in srch_image_list:
        srch_image_concat.append(fits.getdata(image))
    srch_final_image = np.sum(srch_image_concat, axis=0)
    
    for image in temp_image_list:
        temp_image_concat.append(fits.getdata(image))
    temp_final_image = np.sum(temp_image_concat, axis=0)
    
    for image in diff_image_list:
        diff_image_concat.append(fits.getdata(image))
    diff_final_image = np.sum(diff_image_concat, axis=0)
    
    #plot temp, search, diff cols
    ax[0,i].imshow(temp_final_image, cmap='gray') #, vmin=-100, vmax=800)
    ax[0,i].axis('off');
    
    ax[1,i].imshow(srch_final_image, cmap='gray') #, vmin=-100, vmax=800)
    ax[1,i].axis('off');
    
    ax[2,i].imshow(diff_final_image, cmap='gray') #, vmin=-100, vmax=800)
    ax[2,i].axis('off');
    fig.subplots_adjust(wspace=0, hspace=0)

# %%
fig, ax = plt.subplots(ncols=3, nrows=1, sharex=False, sharey=False, dpi=120, figsize=(10,10))
#i = 0
ax[0].imshow(temp_final_image, cmap='gray') #, vmin=-100, vmax=800)
ax[0].axis('off');
    
ax[1].imshow(srch_final_image, cmap='gray') #, vmin=-100, vmax=800)
ax[1].axis('off');
    
ax[2].imshow(diff_final_image, cmap='gray') #, vmin=-100, vmax=800)
ax[2].axis('off');
fig.subplots_adjust(wspace=0, hspace=0)

# %%
image_hist = plt.hist(final_image.flatten(), 1000)

# %%
plt.imshow(final_image, cmap='gray', vmin=-200, vmax=800)
print('Min:', np.min(final_image))
print('Max:', np.max(final_image))
# Out:
# ('Min:', -296.9546203613281)
# ('Max:', 1145.9658203125)

# %%
fig, ax = plt.subplots(ncols=3, nrows=1, sharex=False, sharey=False, dpi=120)
srch1 = fits.open('479420/srch19438773.fits')
srch2 = fits.open('479420/srch19510524.fits')
srch3 = fits.open('479420/srch19436627.fits')
image_data1 = srch1[0].data
image_data2 = srch2[0].data
image_data3 = srch3[0].data
ax[0].imshow(image_data1, cmap='gray')
ax[1].imshow(image_data2, cmap='gray')
ax[2].imshow(image_data3, cmap='gray')
ax[0].axis('off');
ax[1].axis('off');
ax[2].axis('off');

# %%
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
from astropy.convolution import Gaussian2DKernel
from scipy.signal import convolve as scipy_convolve
from astropy.convolution import convolve

# %%
gauss = Gaussian2DKernel(stddev=2)

# %%
fig, ax = plt.subplots(ncols=3, nrows=11, sharex=False, sharey=False, dpi=120, figsize=(10,30))
plt.rc('font',family='Serif')

srch_list = [g for g in glob('desgw*/srch*.fits')]
temp_list = [g for g in glob('desgw*/temp*.fits')]
diff_list = [g for g in glob('desgw*/diff*.fits')]

cands = ['desgw190510a', 'desgw190510b', 'desgw190510c', 'desgw190510d', 'desgw190510e', 'desgw190510f','desgw190510g', 'desgw190510h', 'desgw190510i','desgw190510j', 'desgw190510k']
for i, cand in enumerate(cands):
    srch_image_list = filter(lambda x:cand in x, srch_list)
    temp_image_list = filter(lambda x:cand in x, temp_list)
    diff_image_list = filter(lambda x:cand in x, diff_list) #make list of just desgw190510*/ dir
    
    gsrch = filter(lambda x:'srch_r' in x, srch_image_list)
    gtemp = filter(lambda x:'temp_r' in x, temp_image_list)
    gdiff = filter(lambda x:'diff_r' in x, diff_image_list)
    
#     print cand
#     print gsrch
#     print gtemp
#     print gdiff
#     print
    
    if gsrch:
        g1 = fits.open(gsrch[0])
        g2 = fits.open(gtemp[0])
        g3 = fits.open(gdiff[0])
        image_data1 = g1[0].data
        image_data2 = g2[0].data
        image_data3 = g3[0].data

    #plot search, temp, diff cols
        ax[i,0].imshow(image_data1, cmap='gray') #, vmin=-100, vmax=800)
        
        #ax[i,0].set(ylabel=cand)
        ax[i,0].set_ylabel(cand, fontsize=10)
        
        ax[i,0].xaxis.set_visible(False)
        ax[i,0].tick_params(left=False, labelleft=False)
    
        ax[i,1].imshow(image_data2, cmap='gray') #, vmin=-100, vmax=800)
        ax[i,1].xaxis.set_visible(False)
        ax[i,1].yaxis.set_visible(False)
    
        ax[i,2].imshow(image_data3, cmap='gray') #, vmin=-100, vmax=800)
        ax[i,2].xaxis.set_visible(False)
        ax[i,2].yaxis.set_visible(False)
        
        
    else:
        rsrch = filter(lambda x:'srch_g.fits' in x, srch_image_list)
        rtemp = filter(lambda x:'temp_g.fits' in x, temp_image_list)
        rdiff = filter(lambda x:'diff_g.fits' in x, diff_image_list)
        r1 = fits.open(rsrch[0])
        r2 = fits.open(rtemp[0])
        r3 = fits.open(rdiff[0])
        image_data1 = r1[0].data
        image_data2 = r2[0].data
        image_data3 = r3[0].data
        
        ax[i,0].imshow(image_data1, cmap='gray') #, vmin=-100, vmax=800)
        #ax[i,0].axis('off');
        ax[i,0].xaxis.set_visible(False)
        ax[i,0].tick_params(left=False, labelleft=False)
        ax[i,0].set_ylabel(cand, fontsize=10)
    
        ax[i,1].imshow(image_data2, cmap='gray') #, vmin=-100, vmax=800)
        #ax[i,1].axis('off');
        ax[i,1].xaxis.set_visible(False)
        ax[i,1].yaxis.set_visible(False)
    
        ax[i,2].imshow(image_data3, cmap='gray') #, vmin=-100, vmax=800)
        #ax[i,2].axis('off');
        ax[i,2].xaxis.set_visible(False)
        ax[i,2].yaxis.set_visible(False)
        
        
        
#         fig.delaxes(ax[i][0])
#         fig.delaxes(ax[i][1])
#         fig.delaxes(ax[i][2])
    fig.subplots_adjust(wspace=0.6, hspace=0)
    
    ax[0,0].set_title('Search', fontsize=12)#, y=-0.25)
    ax[0,1].set_title('Template', fontsize=12)#, y=-0.25)
    ax[0,2].set_title('Difference', fontsize=12)#, y =-0.25)
#     for a in ax.flat:
#         a.set(xlabel='x-label', ylabel=['y1', 'y2'])
#     for a in ax.flat:
#         a.label_outer()

#plt.savefig("stamps190510_r.pdf", bbox_inches='tight')

# %%
srch_list = [g for g in glob('desgw*h/srch*.fits')]
temp_list = [g for g in glob('desgw*h/temp*.fits')]
diff_list = [g for g in glob('desgw*h/diff*.fits')]

# %%
srch_list
# Out:
# ['desgw190510h/srch_z_1.fits',
#  'desgw190510h/srch_r_1.fits',
#  'desgw190510h/srch_g_1.fits',
#  'desgw190510h/srch_r_2.fits',
#  'desgw190510h/srch_z_2.fits']

# %%
import matplotlib.gridspec as gridspec
from matplotlib.patches import Rectangle

# %%
#fig, ax = plt.subplots(ncols=6, nrows=6, figsize=(20,20))
fig = plt.figure(figsize=(30,30))
ax1 = fig.subplots(6,3, gridspec_kw=dict(left=0.05, right=0.43, wspace=0.))
ax2 = fig.subplots(6,3, gridspec_kw=dict(left=0.45, right=0.84, wspace=0.))
ax3 = fig.subplots(6,3, gridspec_kw=dict(left=0.85, right=1.23, wspace=0.))

plt.rc('font',family='Serif')
fsize = 30

#gs1 = gridspec.GridSpec(4, 4)
#gs1.update(wspace=0, hspace=0)

srch_list = [g for g in glob('desgw*/srch*.fits')]
temp_list = [g for g in glob('desgw*/temp*.fits')]
diff_list = [g for g in glob('desgw*/diff*.fits')]

cands1 = ['desgw190510a', 'desgw190510b', 'desgw190510c', 'desgw190510d']
cands2 = ['desgw190510e', 'desgw190510f','desgw190510g', 'desgw190510h']
cands3 = ['desgw190510i','desgw190510j', 'desgw190510k']

cands6 = ['desgw190510a', 'desgw190510b', 'desgw190510c', 'desgw190510d', 'desgw190510e', 'desgw190510f']
cands5 = ['desgw190510g', 'desgw190510h', 'desgw190510i','desgw190510j', 'desgw190510k']

for i, cand in enumerate(cands6):
    srch_image_list = filter(lambda x:cand in x, srch_list)
    temp_image_list = filter(lambda x:cand in x, temp_list)
    diff_image_list = filter(lambda x:cand in x, diff_list) #make list of just desgw190510*/ dir
    
    gsrch = filter(lambda x:'srch_r' in x, srch_image_list)
    gtemp = filter(lambda x:'temp_r' in x, temp_image_list)
    gdiff = filter(lambda x:'diff_r' in x, diff_image_list)
    
#     print cand
#     print gsrch
#     print gtemp
#     print gdiff
#     print
    
    if gsrch:
        g1 = fits.open(gsrch[0])
        g2 = fits.open(gtemp[0])
        g3 = fits.open(gdiff[0])
        image_data1 = g1[0].data
        image_data2 = g2[0].data
        image_data3 = g3[0].data

    #plot search, temp, diff cols
        ax1[i,0].imshow(image_data1, cmap='gray') #, vmin=-100, vmax=800)
        ax1[i,1].imshow(image_data2, cmap='gray') #, vmin=-100, vmax=800)
        ax1[i,2].imshow(image_data3, cmap='gray') #, vmin=-100, vmax=800)
        ax1[i,2].set_aspect('equal')
        ax1[i,1].set_aspect('equal')
        ax1[i,0].set_aspect('equal')
        
        ax1[i,0].set(ylabel=cand)
        ax1[i,0].set_ylabel(cand, fontsize=fsize)
        
        ax1[i,0].xaxis.set_visible(False)
        ax1[i,0].tick_params(left=False, labelleft=False)
        
        ax1[i,1].xaxis.set_visible(False)
        ax1[i,1].yaxis.set_visible(False)
        
        ax1[i,2].xaxis.set_visible(False)
        ax1[i,2].yaxis.set_visible(False)
        
    else:
        print("using g band "+str(cand))
        rsrch = filter(lambda x:'srch_g.fits' in x, srch_image_list)
        rtemp = filter(lambda x:'temp_g.fits' in x, temp_image_list)
        rdiff = filter(lambda x:'diff_g.fits' in x, diff_image_list)
        r1 = fits.open(rsrch[0])
        r2 = fits.open(rtemp[0])
        r3 = fits.open(rdiff[0])
        image_data1 = r1[0].data
        image_data2 = r2[0].data
        image_data3 = r3[0].data
        
        ax1[i,0].imshow(image_data1, cmap='gray')
        ax1[i,1].imshow(image_data2, cmap='gray')
        ax1[i,2].imshow(image_data3, cmap='gray')

        ax1[i,0].set_ylabel(cand, fontsize=fsize)
        
        ax1[i,0].xaxis.set_visible(False)
        ax1[i,0].tick_params(left=False, labelleft=False)
         
        ax1[i,1].xaxis.set_visible(False)
        ax1[i,1].yaxis.set_visible(False)
    
        ax1[i,2].xaxis.set_visible(False)
        ax1[i,2].yaxis.set_visible(False)
        
        
#### add 5x3 next to 6x3 ###
for i, cand in enumerate(cands5):
    srch_image_list = filter(lambda x:cand in x, srch_list)
    temp_image_list = filter(lambda x:cand in x, temp_list)
    diff_image_list = filter(lambda x:cand in x, diff_list) #make list of just desgw190510*/ dir
    gsrch = filter(lambda x:'srch_r' in x, srch_image_list)
    gtemp = filter(lambda x:'temp_r' in x, temp_image_list)
    gdiff = filter(lambda x:'diff_r' in x, diff_image_list)

    if gsrch:
        g1 = fits.open(gsrch[0])
        g2 = fits.open(gtemp[0])
        g3 = fits.open(gdiff[0])
        image_data1 = g1[0].data
        image_data2 = g2[0].data
        image_data3 = g3[0].data

    #plot search, temp, diff cols
        ax2[i,0].imshow(image_data1, cmap='gray') #, vmin=-100, vmax=800)
        ax2[i,1].imshow(image_data2, cmap='gray') #, vmin=-100, vmax=800)
        ax2[i,2].imshow(image_data3, cmap='gray') #, vmin=-100, vmax=800)
        ax2[i,2].set_aspect('equal')
        ax2[i,1].set_aspect('equal')
        ax2[i,0].set_aspect('equal')
        
        ax2[i,0].set(ylabel=cand)
        ax2[i,0].set_ylabel(cand, fontsize=fsize)
        
        ax2[i,0].xaxis.set_visible(False)
        ax2[i,0].tick_params(left=False, labelleft=False)
        
        ax2[i,1].xaxis.set_visible(False)
        ax2[i,1].yaxis.set_visible(False)
        
        ax2[i,2].xaxis.set_visible(False)
        ax2[i,2].yaxis.set_visible(False)
        
    else:
        print("using g band "+str(cand))
        rsrch = filter(lambda x:'srch_g.fits' in x, srch_image_list)
        rtemp = filter(lambda x:'temp_g.fits' in x, temp_image_list)
        rdiff = filter(lambda x:'diff_g.fits' in x, diff_image_list)
        r1 = fits.open(rsrch[0])
        r2 = fits.open(rtemp[0])
        r3 = fits.open(rdiff[0])
        image_data1 = r1[0].data
        image_data2 = r2[0].data
        image_data3 = r3[0].data
        
        ax2[i,0].imshow(image_data1, cmap='gray')
        ax2[i,1].imshow(image_data2, cmap='gray')
        ax2[i,2].imshow(image_data3, cmap='gray')

        ax2[i,0].set_ylabel(cand, fontsize=fsize)
        
        ax2[i,0].xaxis.set_visible(False)
        ax2[i,0].tick_params(left=False, labelleft=False)
         
        ax2[i,1].xaxis.set_visible(False)
        ax2[i,1].yaxis.set_visible(False)
    
        ax2[i,2].xaxis.set_visible(False)
        ax2[i,2].yaxis.set_visible(False)
        
        
### add growth cand ###
srch_list = [g for g in glob('growth_stamps/*/srch*.fits')]
temp_list = [g for g in glob('growth_stamps/*/temp*.fits')]
diff_list = [g for g in glob('growth_stamps/*/diff*.fits')]

cands1 = ['DG19nouo', 'DG19llhk', 'DG19oahn', 'DG19qcso', 'DG19ukvo']

for i, cand in enumerate(cands1):
    srch_image_list = filter(lambda x:cand in x, srch_list)
    temp_image_list = filter(lambda x:cand in x, temp_list)
    diff_image_list = filter(lambda x:cand in x, diff_list) #make list of just desgw190510*/ dir
    
    gsrch = filter(lambda x:'srch_r' in x, srch_image_list)
    gtemp = filter(lambda x:'temp_r' in x, temp_image_list)
    gdiff = filter(lambda x:'diff_r' in x, diff_image_list)
    
    if gsrch:
        g1 = fits.open(gsrch[0])
        g2 = fits.open(gtemp[0])
        g3 = fits.open(gdiff[0])
        image_data1 = g1[0].data
        image_data2 = g2[0].data
        image_data3 = g3[0].data

    #plot search, temp, diff cols
        ax3[i,0].imshow(image_data1, cmap='gray') #, vmin=-100, vmax=800)
        ax3[i,1].imshow(image_data2, cmap='gray') #, vmin=-100, vmax=800)
        ax3[i,2].imshow(image_data3, cmap='gray') #, vmin=-100, vmax=800)
        ax3[i,2].set_aspect('equal')
        ax3[i,1].set_aspect('equal')
        ax3[i,0].set_aspect('equal')
        
        ax3[i,0].set(ylabel=cand)
        ax3[i,0].set_ylabel(cand, fontsize=fsize)
        
        ax3[i,0].xaxis.set_visible(False)
        ax3[i,0].tick_params(left=False, labelleft=False)
        
        ax3[i,1].xaxis.set_visible(False)
        ax3[i,1].yaxis.set_visible(False)
        
        ax3[i,2].xaxis.set_visible(False)
        ax3[i,2].yaxis.set_visible(False)
        
    else:
        print("using g band "+str(cand))
        rsrch = filter(lambda x:'srch_g.fits' in x, srch_image_list)
        rtemp = filter(lambda x:'temp_g.fits' in x, temp_image_list)
        rdiff = filter(lambda x:'diff_g.fits' in x, diff_image_list)
        r1 = fits.open(rsrch[0])
        r2 = fits.open(rtemp[0])
        r3 = fits.open(rdiff[0])
        image_data1 = r1[0].data
        image_data2 = r2[0].data
        image_data3 = r3[0].data
        
        ax3[i,0].imshow(image_data1, cmap='gray')
        ax3[i,1].imshow(image_data2, cmap='gray')
        ax3[i,2].imshow(image_data3, cmap='gray')

        ax3[i,0].set_ylabel(cand, fontsize=fsize)
        
        ax3[i,0].xaxis.set_visible(False)
        ax3[i,0].tick_params(left=False, labelleft=False)
         
        ax3[i,1].xaxis.set_visible(False)
        ax3[i,1].yaxis.set_visible(False)
    
        ax3[i,2].xaxis.set_visible(False)
        ax3[i,2].yaxis.set_visible(False)

### special ###
cand = 'DG19bexl'
srch_image_list = filter(lambda x:cand in x, srch_list)
temp_image_list = filter(lambda x:cand in x, temp_list)
diff_image_list = filter(lambda x:cand in x, diff_list) #make list of just desgw190510*/ dir
    
gsrch = filter(lambda x:'srch_r' in x, srch_image_list)
gtemp = filter(lambda x:'temp_r' in x, temp_image_list)
gdiff = filter(lambda x:'diff_r' in x, diff_image_list)
    
g1 = fits.open(gsrch[0])
g2 = fits.open(gtemp[0])
g3 = fits.open(gdiff[0])
image_data1 = g1[0].data
image_data2 = g2[0].data
image_data3 = g3[0].data

ax2[5,0].imshow(image_data1, cmap='gray') #, vmin=-100, vmax=800)
ax2[5,1].imshow(image_data2, cmap='gray') #, vmin=-100, vmax=800)
ax2[5,2].imshow(image_data3, cmap='gray') #, vmin=-100, vmax=800)
ax2[5,2].set_aspect('equal')
ax2[5,1].set_aspect('equal')
ax2[5,0].set_aspect('equal')
        
ax2[5,0].set(ylabel=cand)
ax2[5,0].set_ylabel(cand, fontsize=fsize)
        
ax2[5,0].xaxis.set_visible(False)
ax2[5,0].tick_params(left=False, labelleft=False)
        
ax2[5,1].xaxis.set_visible(False)
ax2[5,1].yaxis.set_visible(False)
        
ax2[5,2].xaxis.set_visible(False)
ax2[5,2].yaxis.set_visible(False)

#### add "missing" cand ootl ####
cand = 'DG19ootl'
ax3[5,0].imshow(cutoutsrch.data, origin='lower',cmap='gray')
ax3[5,1].imshow(cutouttemp.data, origin='lower',cmap='gray')
ax3[5,2].imshow(cutoutdiff.data, origin='lower',cmap='gray')
ax3[5,0].set(ylabel=cand)
ax3[5,0].set_ylabel(cand, fontsize=fsize)
        
ax3[5,0].xaxis.set_visible(False)
ax3[5,0].tick_params(left=False, labelleft=False)
        
ax3[5,1].xaxis.set_visible(False)
ax3[5,1].yaxis.set_visible(False)
        
ax3[5,2].xaxis.set_visible(False)
ax3[5,2].yaxis.set_visible(False)    

# rec = Rectangle((-10,-4.5),188,60,fill=False,lw=2, color='red')
# rec = ax2[5,0].add_patch(rec)
# rec.set_clip_on(False)

####

#fig.subplots_adjust(wspace=0.2, hspace=0.1)

ax1[0,0].set_title('Search', fontsize=fsize);
ax1[0,1].set_title('Template', fontsize=fsize);
ax1[0,2].set_title('Difference', fontsize=fsize);
ax2[0,0].set_title('Search', fontsize=fsize);
ax2[0,1].set_title('Template', fontsize=fsize);
ax2[0,2].set_title('Difference', fontsize=fsize);
ax3[0,0].set_title('Search', fontsize=fsize);
ax3[0,1].set_title('Template', fontsize=fsize);
ax3[0,2].set_title('Difference', fontsize=fsize);

#line = plt.Line2D((.5,.5),(.1,.9), color="blue", linewidth=3)
#fig.add_artist(line)

# only for cands3 list
# fig.delaxes(ax2[5][0])
# fig.delaxes(ax2[5][1])
# fig.delaxes(ax2[5][2])

#plt.savefig("190510_AllrStampsExceptak_allgrowth_withootl.pdf", bbox_inches='tight')
# Out:
# using g band desgw190510a
# using g band desgw190510k
# using g band DG19ukvo

# %%
# fig, ax = plt.subplots(ncols=3, nrows=1, figsize=(15,20), sharey=False)
# ax[0].imshow(mpimg.imread('test190510_a-d.png'))
# ax[1].imshow(mpimg.imread('test190510_e-h.png'))
# ax[2].imshow(mpimg.imread('test190510_i-k.png'))


# for a in ax:
#     a.xaxis.set_visible(False)
#     a.yaxis.set_visible(False)
#     a.set_anchor('N')

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import numpy as np

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.subplots(6,3, gridspec_kw=dict(left=0.05, right=0.43, wspace=0.))
#ax2 = fig.subplots(6,3, gridspec_kw=dict(left=0.45, right=0.84, wspace=0.))

plt.rc('font',family='Serif')

#gs1 = gridspec.GridSpec(4, 4)
#gs1.update(wspace=0, hspace=0)

srch_list = [g for g in glob('growth_stamps/*/srch*.fits')]
temp_list = [g for g in glob('growth_stamps/*/temp*.fits')]
diff_list = [g for g in glob('growth_stamps/*/diff*.fits')]

cands1 = ['DG19bexl','DG19nouo', 'DG19llhk', 'DG19oahn', 'DG19qcso', 'DG19ukvo']

# cands2 = ['desgw190510e', 'desgw190510f','desgw190510g', 'desgw190510h']
# cands3 = ['desgw190510i','desgw190510j', 'desgw190510k']

# cands6 = ['desgw190510a', 'desgw190510b', 'desgw190510c', 'desgw190510d', 'desgw190510e', 'desgw190510f']
# cands5 = ['desgw190510g', 'desgw190510h', 'desgw190510i','desgw190510j', 'desgw190510k']

for i, cand in enumerate(cands1):
    srch_image_list = filter(lambda x:cand in x, srch_list)
    temp_image_list = filter(lambda x:cand in x, temp_list)
    diff_image_list = filter(lambda x:cand in x, diff_list) #make list of just desgw190510*/ dir
    
    gsrch = filter(lambda x:'srch_r' in x, srch_image_list)
    gtemp = filter(lambda x:'temp_r' in x, temp_image_list)
    gdiff = filter(lambda x:'diff_r' in x, diff_image_list)
    
#     print cand
#     print gsrch
#     print gtemp
#     print gdiff
#     print
    
    if gsrch:
        g1 = fits.open(gsrch[0])
        g2 = fits.open(gtemp[0])
        g3 = fits.open(gdiff[0])
        image_data1 = g1[0].data
        image_data2 = g2[0].data
        image_data3 = g3[0].data

    #plot search, temp, diff cols
        ax1[i,0].imshow(image_data1, cmap='gray') #, vmin=-100, vmax=800)
        ax1[i,1].imshow(image_data2, cmap='gray') #, vmin=-100, vmax=800)
        ax1[i,2].imshow(image_data3, cmap='gray') #, vmin=-100, vmax=800)
        ax1[i,2].set_aspect('equal')
        ax1[i,1].set_aspect('equal')
        ax1[i,0].set_aspect('equal')
        
        ax1[i,0].set(ylabel=cand)
        ax1[i,0].set_ylabel(cand, fontsize=20)
        
        ax1[i,0].xaxis.set_visible(False)
        ax1[i,0].tick_params(left=False, labelleft=False)
        
        ax1[i,1].xaxis.set_visible(False)
        ax1[i,1].yaxis.set_visible(False)
        
        ax1[i,2].xaxis.set_visible(False)
        ax1[i,2].yaxis.set_visible(False)
        
    else:
        print("using g band "+str(cand))
        rsrch = filter(lambda x:'srch_g.fits' in x, srch_image_list)
        rtemp = filter(lambda x:'temp_g.fits' in x, temp_image_list)
        rdiff = filter(lambda x:'diff_g.fits' in x, diff_image_list)
        r1 = fits.open(rsrch[0])
        r2 = fits.open(rtemp[0])
        r3 = fits.open(rdiff[0])
        image_data1 = r1[0].data
        image_data2 = r2[0].data
        image_data3 = r3[0].data
        
        ax1[i,0].imshow(image_data1, cmap='gray')
        ax1[i,1].imshow(image_data2, cmap='gray')
        ax1[i,2].imshow(image_data3, cmap='gray')

        ax1[i,0].set_ylabel(cand, fontsize=20)
        
        ax1[i,0].xaxis.set_visible(False)
        ax1[i,0].tick_params(left=False, labelleft=False)
         
        ax1[i,1].xaxis.set_visible(False)
        ax1[i,1].yaxis.set_visible(False)
    
        ax1[i,2].xaxis.set_visible(False)
        ax1[i,2].yaxis.set_visible(False)
        
fsize = 20
ax1[0,0].set_title('Search', fontsize=fsize);
ax1[0,1].set_title('Template', fontsize=fsize);
ax1[0,2].set_title('Difference', fontsize=fsize);
# ax2[0,0].set_title('Search', fontsize=fsize);
# ax2[0,1].set_title('Template', fontsize=fsize);
# ax2[0,2].set_title('Difference', fontsize=fsize);

#line = plt.Line2D((.5,.5),(.1,.9), color="blue", linewidth=3)
#fig.add_artist(line)

## only for cands3 list
# fig.delaxes(ax2[5][0])
# fig.delaxes(ax2[5][1])
# fig.delaxes(ax2[5][2])
# Out:
# using g band DG19ukvo

# %%
dats = [d for d in glob('/data/des41.a/data/desgw/O3FULL/Post-Processing/dp700_v2/makedatafiles/LightCurvesReal/*.dat')]

# %%
d = dats[0]
f = open(d,'r')
lines = f.readlines()
f.close()
for i,l in enumerate(lines):
    #print l,i
    if l.startswith("OBS:"):
        print l
# Out:
# OBS:   58613.968  z  WS   5.5175e+02   5.1749e+01  4096   0.373  30.503 2.193 75.5 23.1 1.02 1742.39 1446.11  20190510  856753   20   19475041
#
# OBS:   58613.993  r  WS   5.1652e+02   2.8449e+01  4608   0.410  30.820 2.616 37.5 7.7 1.02 1760.59 1460.02  20190510  856781   20   19453513
#
# OBS:   58614.018  g  WS   2.7985e+02   3.0874e+01  4098   0.536  30.562 3.358 30.1 5.0 1.07 1763.09 1465.55  20190510  856809   20   19508016

# %% [markdown]
# ## Find lost growth cands

# %%
from astropy.cosmology import FlatLambdaCDM
from astropy import units as u
from astropy.coordinates import SkyCoord
import easyaccess as ea
import pandas as pd

# %%
## name ra dec
#DG19ukvo 89.21146 -33.44248
#DG19llhk 90.86311 -32.38554

#47  89.211524 -33.309060     700  19459113
#48  89.212222 -33.333374     700  19459111

# rag, decg = 89.21146, -33.44248 ## ukvo
# #rag, decg = 90.86311, -32.38554 ## llhk

# #rades, decdes = 89.211524, -33.309060
# rades, decdes = 89.212222, -33.333374 ## for ukvo - 0.109

# growth = SkyCoord(rag, decg, unit='degree')
# cand = SkyCoord(rades, decdes, unit='degree')
# sep = cand.separation(growth)
# print sep.deg

growth = {} #[ra, dec]
growth['DG19bexl'] = [90.45378, -28.66039]
growth['DG19nouo'] = [92.0013, -31.66915]
growth['DG19ootl'] = [87.03556, -36.07611]
growth['DG19ukvo'] = [89.21146, -33.44248]
growth['DG19llhk'] = [90.86311, -32.38554]
growth['DG19oahn'] = [86.33527, -26.84768]
growth['DS19qcso'] = [88.208631, -30.381382]

print growth
# Out:
# {'DG19ootl': [87.03556, -36.07611], 'DS19qcso': [88.208631, -30.381382], 'DG19nouo': [92.0013, -31.66915], 'DG19bexl': [90.45378, -28.66039], 'DG19ukvo': [89.21146, -33.44248], 'DG19llhk': [90.86311, -32.38554], 'DG19oahn': [86.33527, -26.84768]}

# %%
con = ea.connect('destest')
# Out:
# Connecting to DB ** destest ** ...

# %%
## look at snobs for all missing cands
dl = 0.1
best = {}
bad = []
for key, val in growth.iteritems():
    r, d = val[0], val[1]
    rahigh, ralow = r+dl, r-dl
    dechigh, declow = d+dl, d-dl
    query = ("SELECT RA, DEC, SEASON, EXPNUM, CCDNUM, SNOBJID FROM SNOBS" 
             " WHERE  RA < "+str(rahigh)+" and RA > "+str(ralow)+" and DEC < "+str(dechigh)+" and DEC > "+str(declow)+" "
             "and SEASON = 700")
    df = con.query_to_pandas(query)
    
    if df.empty:
        bad.append(key)
        continue
        
    for index, row in df.iterrows():
        ra, dec = df['RA'], df['DEC']
        match = SkyCoord(ra, dec, unit='degree')
        cand = SkyCoord(val[0], val[1], unit='degree')
        sep = cand.separation(match)
        df['SEP']= sep

    print key, val[0], val[1]
    print df.sort_values('SEP')
    print
    minobjid = df['SEP'].min()
#    print minobjid
    mindf = df.loc[df['SEP'] == minobjid]
#    print mindf
    best[key] = [mindf['RA'].values[0], mindf['DEC'].values[0], mindf['SNOBJID'].values[0], mindf['SEP'].values[0]]
    
print bad
# Out:
# DG19ootl 87.03556 -36.07611
#            RA        DEC  SEASON  EXPNUM  CCDNUM   SNOBJID       SEP
# 6   87.040693 -36.076949     700  856751      47  19432925  0.004233
# 5   87.062173 -36.083356     700  856751      47  19432923  0.022696
# 4   87.074248 -36.038109     700  856751      47  19432920  0.049217
# 8   87.010685 -36.146260     700  856779      53  19441418  0.072972
# 10  87.010685 -36.146260     700  856779      53  19452678  0.072972
# 2   86.957827 -36.121390     700  856751      47  19432911  0.077429
# 1   86.943643 -36.125539     700  856751      47  19432908  0.089212
# 3   86.970112 -36.000011     700  856751      47  19432914  0.092693
# 7   86.948159 -36.166667     700  856779      53  19441412  0.114825
# 9   86.948159 -36.166667     700  856779      53  19452674  0.114825
# 11  86.948163 -36.166671     700  856807      53  19514335  0.114827
# 0   86.948150 -36.166668     700  856751      53  19428133  0.114831
#
# DS19qcso 88.208631 -30.381382
# ...

# %%
best
# Out:
# {'DG19bexl': [90.453777, -28.6604273, 19507821, 3.739277611100462e-05],
#  'DG19llhk': [90.8630786, -32.3855462, 19522550, 2.723133764541785e-05],
#  'DG19nouo': [92.0012824, -31.6691436, 19504037, 1.628919993718555e-05],
#  'DG19oahn': [86.4273168, -26.8280532, 19489600, 0.0844447319072519],
#  'DG19ootl': [87.0406933, -36.0769495, 19432925, 0.004232974595840694],
#  'DG19ukvo': [89.2011905, -33.3603605, 19501186, 0.08256581761513537],
#  'DS19qcso': [88.2085893, -30.3814074, 19486431, 4.403708613366399e-05]}

# %%
## look at sncand for all missing cands
dl = 0.15
nomatch = []
for key, val in best.iteritems():
    r, d = val[0], val[1]
    rahigh, ralow = r+dl, r-dl
    dechigh, declow = d+dl, d-dl
    query = ("SELECT RA, DEC, SEASON, SNID FROM SNCAND" 
             " WHERE  RA < "+str(rahigh)+" and RA > "+str(ralow)+" and DEC < "+str(dechigh)+" and DEC > "+str(declow)+" "
             "and SEASON = 700")
    df = con.query_to_pandas(query)
    #print df
    if df.empty:
        nomatch.append(key)
        continue
    for index, row in df.iterrows():
        ra, dec = df['RA'], df['DEC']
        match = SkyCoord(ra, dec, unit='degree')
        cand = SkyCoord(val[0], val[1], unit='degree')
        sep = cand.separation(match)
        df['SEP']= sep

    print key, val[0], val[1]
    print df.sort_values('SEP')
    print
    
print nomatch
# Out:
# DG19ootl 87.0406933 -36.0769495
#           RA        DEC  SEASON    SNID       SEP
# 0  87.146843 -35.994357     700  480400  0.119120
# 1  87.154610 -36.167024     700  480253  0.128766
#
# DG19nouo 92.0012824 -31.6691436
#           RA        DEC  SEASON    SNID       SEP
# 1  92.001300 -31.669157     700  479981  0.000020
# 4  91.999757 -31.568678     700  479969  0.100474
# 3  92.111066 -31.731899     700  479983  0.112529
# 6  91.985482 -31.552244     700  479443  0.117672
# 5  91.883754 -31.733897     700  479484  0.119128
# 2  92.014319 -31.799302     700  479982  0.130630
# 0  91.944292 -31.800834     700  479980  0.140327
#
# DG19bexl 90.453777 -28.6604273
#           RA        DEC  SEASON    SNID       SEP
# 4  90.453749 -28.660396     700  480089  0.000040
# 3  90.388186 -28.698905     700  480088  0.069223
# 2  90.389733 -28.700867     700  480361  0.069226
# 0  90.423192 -28.769777     700  479652  0.112592
# 5  90.462733 -28.775535     700  480091  0.115376
# ...

# %% [markdown]
# # CHECK ALL GROWTH CANDS

# %%
growth = {}
growth['DG19lcnl'] = [87.1469, -35.99441]
growth['DG19ukvo'] = [89.21146, -33.44248]
growth['DG19nanl'] = [87.31139, -35.95584]
growth['DG19zaxn'] = [92.30795, -35.14981]
growth['DG19etsk'] = [89.10091, -30.47397]
growth['DG19yhhm'] = [91.93699, -30.82476]
growth['DG19llhk'] = [90.86311, -32.38554]
growth['DG19fqqk'] = [92.85149, -36.51731]
growth['DG19bexl'] = [90.45378, -28.66039]
growth['DG19ootl'] = [87.03556, -36.07611]
growth['DG19nouo'] = [92.0013, -31.66915]
growth['DG19oahn'] = [86.33527, -26.84768]
growth['DS19qcso'] = [88.208631, -30.381382]

# %%
dl = 0.1
best = {}
bad = []
for key, val in growth.iteritems():
    r, d = val[0], val[1]
    rahigh, ralow = r+dl, r-dl
    dechigh, declow = d+dl, d-dl
    query = ("SELECT RA, DEC, SEASON, EXPNUM, CCDNUM, SNOBJID FROM SNOBS" 
             " WHERE  RA < "+str(rahigh)+" and RA > "+str(ralow)+" and DEC < "+str(dechigh)+" and DEC > "+str(declow)+" "
             "and SEASON = 700")
    df = con.query_to_pandas(query)
    if df.empty:
        bad.append(key)
        continue
    
    for index, row in df.iterrows():
        ra, dec = df['RA'], df['DEC']
        match = SkyCoord(ra, dec, unit='degree')
        cand = SkyCoord(val[0], val[1], unit='degree')
        sep = cand.separation(match)
        df['SEP']= sep

    print key, val[0], val[1]
    print df.sort_values('SEP')
    print
    minobjid = df['SEP'].min()
#    print minobjid
    mindf = df.loc[df['SEP'] == minobjid]
#    print mindf
    best[key] = [mindf['RA'].values[0], mindf['DEC'].values[0], mindf['SNOBJID'].values[0], mindf['SEP'].values[0]]
print bad
# Out:
# DG19yhhm 91.93699 -30.82476
#             RA        DEC  SEASON  EXPNUM  CCDNUM   SNOBJID       SEP
# 2    91.936986 -30.824741     700  856784      53  19460209  0.000019
# 60   91.936961 -30.824753     700  856756      53  19464041  0.000026
# 67   91.946017 -30.818970     700  856756      53  19464053  0.009675
# 10   91.946137 -30.818931     700  856784      53  19460219  0.009782
# 64   91.940939 -30.814831     700  856756      53  19464048  0.010492
# 8    91.941128 -30.814794     700  856784      53  19460216  0.010580
# 72   91.956886 -30.830564     700  856756      53  19464062  0.018044
# 65   91.942561 -30.844190     700  856756      53  19464050  0.020010
# 99   91.914315 -30.810360     700  856756      52  19471094  0.024219
# 16   91.966218 -30.829321     700  856784      53  19460227  0.025510
# 74   91.960092 -30.841201     700  856756      53  19464066  0.025764
# 66   91.945603 -30.851015     700  856756      53  19464051  0.027277
# ...

# %%
best
# Out:
# {'DG19bexl': [90.453777, -28.6604273, 19507821, 3.739277611100462e-05],
#  'DG19etsk': [89.1009249, -30.4739856, 19495273, 2.020567886229399e-05],
#  'DG19fqqk': [92.8515049, -36.5173108, 19510524, 1.2001482053750327e-05],
#  'DG19lcnl': [87.1468576, -35.9943765, 19519084, 4.7948581859192944e-05],
#  'DG19llhk': [90.8630786, -32.3855462, 19522550, 2.723133764541785e-05],
#  'DG19nanl': [87.3113964, -35.9558377, 19428052, 5.668217148403442e-06],
#  'DG19nouo': [92.0012824, -31.6691436, 19504037, 1.628919993718555e-05],
#  'DG19oahn': [86.4273168, -26.8280532, 19489600, 0.0844447319072519],
#  'DG19ootl': [87.0406933, -36.0769495, 19432925, 0.004232974595840694],
#  'DG19ukvo': [89.2011905, -33.3603605, 19501186, 0.08256581761513537],
#  'DG19yhhm': [91.9369855, -30.8247413, 19460209, 1.909510404996574e-05],
#  'DG19zaxn': [92.3079555, -35.1498366, 19455661, 2.6977465663961092e-05],
#  'DS19qcso': [88.2085893, -30.3814074, 19486431, 4.403708613366399e-05]}

# %%
dl = 0.15
nomatch = []
for key, val in best.iteritems():
    r, d = val[0], val[1]
    rahigh, ralow = r+dl, r-dl
    dechigh, declow = d+dl, d-dl
    query = ("SELECT RA, DEC, SEASON, SNID FROM SNCAND" 
             " WHERE  RA < "+str(rahigh)+" and RA > "+str(ralow)+" and DEC < "+str(dechigh)+" and DEC > "+str(declow)+" "
             "and SEASON = 700")
    df = con.query_to_pandas(query)
    #print df
    if df.empty:
        nomatch.append(key)
        continue
    for index, row in df.iterrows():
        ra, dec = df['RA'], df['DEC']
        match = SkyCoord(ra, dec, unit='degree')
        cand = SkyCoord(val[0], val[1], unit='degree')
        sep = cand.separation(match)
        df['SEP']= sep

    print key, val[0], val[1]
    print df.sort_values('SEP')
    print
    
print nomatch
# Out:
# DG19yhhm 91.9369855 -30.8247413
#           RA        DEC  SEASON    SNID       SEP
# 0  91.936973 -30.824747     700  479596  0.000012
# 1  91.992529 -30.755427     700  479597  0.084149
#
# DG19etsk 89.1009249 -30.4739856
#           RA        DEC  SEASON    SNID       SEP
# 3  89.100926 -30.473987     700  479824  0.000002
# 1  89.071082 -30.568809     700  479822  0.098246
# 2  89.116486 -30.580133     700  479823  0.106990
# 0  88.972731 -30.458218     700  479854  0.111614
#
# DG19zaxn 92.3079555 -35.1498366
#           RA        DEC  SEASON    SNID       SEP
# 0  92.307977 -35.149829     700  479812  0.000019
# 1  92.426327 -35.163125     700  479813  0.097687
#
# DG19fqqk 92.8515049 -36.5173108
#           RA        DEC  SEASON    SNID       SEP
# 1  92.851468 -36.517324     700  479420  0.000033
# 0  92.716506 -36.552305     700  479419  0.113976
#
# DG19lcnl 87.1468576 -35.9943765
#           RA        DEC  SEASON    SNID       SEP
# ...

# %% [markdown]
# # Find missing snobs

# %%
outs = glob('/pnfs/des/persistent/gw/exp/20190510/*/*.out')
fullouts = []
for o in outs:
    if "_" not in o:
        fullouts.append(o)

# %%
missing = {}
missing['DG19ukvo'] = [89.21146, -33.44248]
missing['DG19ootl'] = [87.03556, -36.07611]
missing['DG19oahn'] = [86.33527, -26.84768]

# %%
ukvodf = pd.DataFrame(columns=['expnum','ccd','c1','c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8'])

for key, val in missing.iteritems():
    ra, dec = val[0], val[1]
    for out in fullouts:
        df = pd.read_fwf(out, usecols=(0,2,3,4,5,6,7,8,9,10),header=None)
        df.columns = ['expnum','ccd','c1','c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8']
    
        df['max_ra'] = df[["c1", "c3", 'c5', 'c7']].max(axis=1)
        df['min_ra'] = df[["c1", "c3", 'c5', 'c7']].min(axis=1)
        df['max_dec'] = df[["c2", "c4", 'c6', 'c8']].max(axis=1)
        df['min_dec'] = df[["c2", "c4", 'c6', 'c8']].min(axis=1)
        
        df = df[df.max_ra != 0]
        df = df[df.min_ra != 0]
        df = df[df.max_dec != 0]
        df = df[df.min_dec != 0]
    
        for index, row in df.iterrows():
            if row['min_ra'] <= ra <= row['max_ra'] and row['min_dec'] <= dec <= row['max_dec']:
                print key, out, row['ccd']
#                 exp = out.split('/')[-2]
#                 o = out.split('/')[-1].split('.')[0]
#                 if exp == o:
#                     ukvodf.loc[index] = row
# Out:
# DG19ukvo /pnfs/des/persistent/gw/exp/20190510/856735/388663.out 56.0
# DG19ukvo /pnfs/des/persistent/gw/exp/20190510/856735/404838.out 6.0
# DG19ukvo /pnfs/des/persistent/gw/exp/20190510/856735/716144.out 50.0
# DG19ukvo /pnfs/des/persistent/gw/exp/20190510/856735/809808.out 31.0
# DG19ukvo /pnfs/des/persistent/gw/exp/20190510/856735/408768.out 33.0
# DG19ootl /pnfs/des/persistent/gw/exp/20190510/856751/856751.out 47.0
# DG19ootl /pnfs/des/persistent/gw/exp/20190510/856807/856807.out 47.0
# DG19oahn /pnfs/des/persistent/gw/exp/20190510/856761/856761.out 8.0

# %% [markdown]
# ## look for ukvooooooo

# %%
ukvodf = pd.DataFrame(columns=['expnum','ccd','c1','c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8'])
missing = {}
missing['DG19ukvo'] = [89.21146, -33.44248]

for key, val in missing.iteritems():
    ra, dec = val[0], val[1]
    for out in fullouts:
        df = pd.read_fwf(out, usecols=(0,2,3,4,5,6,7,8,9,10),header=None)
        df.columns = ['expnum','ccd','c1','c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8']
    
        df['max_ra'] = df[["c1", "c3", 'c5', 'c7']].max(axis=1)
        df['min_ra'] = df[["c1", "c3", 'c5', 'c7']].min(axis=1)
        df['max_dec'] = df[["c2", "c4", 'c6', 'c8']].max(axis=1)
        df['min_dec'] = df[["c2", "c4", 'c6', 'c8']].min(axis=1)
        
        df = df[df.max_ra != 0]
        df = df[df.min_ra != 0]
        df = df[df.max_dec != 0]
        df = df[df.min_dec != 0]
            
        for index, row in df.iterrows():
            if row['min_ra'] <= ra <= row['max_ra'] and row['min_dec'] <= dec <= row['max_dec']:
            #if -33.2 <= row['c2'] <= -33.3:
                print key, out, row['ccd']
#                 exp = out.split('/')[-2]
#                 o = out.split('/')[-1].split('.')[0]
#                 if exp == o:
#                     ukvodf.loc[index] = row
#ukvodf.sort_values('c1')
# Out:
# DG19ukvo /pnfs/des/persistent/gw/exp/20190510/856735/388663.out 56.0
# DG19ukvo /pnfs/des/persistent/gw/exp/20190510/856735/404838.out 6.0
# DG19ukvo /pnfs/des/persistent/gw/exp/20190510/856735/716144.out 50.0
# DG19ukvo /pnfs/des/persistent/gw/exp/20190510/856735/809808.out 31.0
# DG19ukvo /pnfs/des/persistent/gw/exp/20190510/856735/408768.out 33.0
# Empty DataFrame
# Columns: [expnum, ccd, c1, c2, c3, c4, c5, c6, c7, c8]
# Index: []

# %%
df = pd.read_fwf('/pnfs/des/persistent/gw/exp/20190510/856735/856735.out', usecols=(0,2,3,4,5,6,7,8,9,10), header=None)
df.columns = ['expnum','ccd','c1','c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8']
ra, dec  = 89.21146, -33.44248

df['max_ra'] = df[["c1", "c3", 'c5', 'c7']].max(axis=1)
df['min_ra'] = df[["c1", "c3", 'c5', 'c7']].min(axis=1)
df['max_dec'] = df[["c2", "c4", 'c6', 'c8']].max(axis=1)
df['min_dec'] = df[["c2", "c4", 'c6', 'c8']].min(axis=1)

# for index, row in df.iterrows():
#     if row['min_ra'] <= ra <= row['max_ra'] and row['min_dec'] <= dec <= row['max_dec']:
#         print index
df.sort_values('min_dec')

# %% [markdown]
# # Check snobs / sncand for reruns (season 94)

# %%
missing = {}
missing['DG19ukvo'] = [89.21146, -33.44248]
missing['DG19ootl'] = [87.03556, -36.07611]
missing['DG19oahn'] = [86.33527, -26.84768]
missing['DS19qcso'] = [88.208631, -30.381382]
missing['DG19llhk'] = [90.86311, -32.38554]

# %%
dl = 0.1
best = {}
bad = []
for key, val in missing.iteritems():
    r, d = val[0], val[1]
    rahigh, ralow = r+dl, r-dl
    dechigh, declow = d+dl, d-dl
    query = ("SELECT RA, DEC, SEASON, EXPNUM, CCDNUM, SNOBJID FROM SNOBS" 
             " WHERE  RA < "+str(rahigh)+" and RA > "+str(ralow)+" and DEC < "+str(dechigh)+" and DEC > "+str(declow)+" "
             "and SEASON = 94")
    df = con.query_to_pandas(query)
    if df.empty:
        bad.append(key)
        continue
    
    for index, row in df.iterrows():
        ra, dec = df['RA'], df['DEC']
        match = SkyCoord(ra, dec, unit='degree')
        cand = SkyCoord(val[0], val[1], unit='degree')
        sep = cand.separation(match)
        df['SEP']= sep

    print key, val[0], val[1]
    print df.sort_values('SEP')
    print
    minobjid = df['SEP'].min()
#    print minobjid
    mindf = df.loc[df['SEP'] == minobjid]
#    print mindf
    best[key] = [mindf['RA'].values[0], mindf['DEC'].values[0], mindf['SNOBJID'].values[0], mindf['SEP'].values[0]]
print bad
# Out:
# DG19ukvo 89.21146 -33.44248
#            RA        DEC  SEASON  EXPNUM  CCDNUM   SNOBJID       SEP
# 14  89.211475 -33.442517      94  856791      52  37458860  0.000039
# 15  89.237493 -33.404133      94  856791      52  37458861  0.044075
# 10  89.159764 -33.428685      94  856791      52  37458856  0.045292
# 17  89.258465 -33.416052      94  856791      52  37458863  0.047301
# 9   89.153859 -33.450966      94  856791      52  37458855  0.048806
# 8   89.150633 -33.453963      94  856791      52  37458854  0.052036
# 16  89.250239 -33.487766      94  856791      52  37458862  0.055655
# 7   89.141762 -33.435730      94  856791      52  37458852  0.058551
# 6   89.141387 -33.427876      94  856791      52  37458853  0.060273
# 5   89.137559 -33.430939      94  856791      52  37458851  0.062741
# 11  89.174232 -33.499997      94  856791      52  37458857  0.065365
# 4   89.131461 -33.442842      94  856791      52  37458850  0.066755
# ...

# %%
best
# Out:
# {'DG19llhk': [90.8631352, -32.3855303, 37458759, 2.3386929824658183e-05],
#  'DG19oahn': [86.3352677, -26.8476699, 33897827, 1.0306359586702382e-05],
#  'DG19ootl': [87.0406931, -36.0769492, 37458669, 0.004232756679153575],
#  'DG19ukvo': [89.211475, -33.4425169, 37458860, 3.8965048703089844e-05],
#  'DS19qcso': [88.2085804, -30.3813928, 37458741, 4.496770048509636e-05]}

# %%
dl = 0.15
nomatch = []
for key, val in missing.iteritems():
    r, d = val[0], val[1]
    rahigh, ralow = r+dl, r-dl
    dechigh, declow = d+dl, d-dl
    query = ("SELECT RA, DEC, SEASON, SNID FROM SNCAND" 
             " WHERE  RA < "+str(rahigh)+" and RA > "+str(ralow)+" and DEC < "+str(dechigh)+" and DEC > "+str(declow)+" "
             "and SEASON = 94")
    df = con.query_to_pandas(query)
    #print df
    if df.empty:
        nomatch.append(key)
        continue
    for index, row in df.iterrows():
        ra, dec = df['RA'], df['DEC']
        match = SkyCoord(ra, dec, unit='degree')
        cand = SkyCoord(val[0], val[1], unit='degree')
        sep = cand.separation(match)
        df['SEP']= sep

    print key, val[0], val[1]
    print df.sort_values('SEP')
    print
    
print nomatch
# Out:
# DG19llhk 90.86311 -32.38554
#           RA        DEC  SEASON    SNID       SEP
# 4  90.863099 -32.385564      94  861102  0.000026
# 2  90.863166 -32.387479      94  861105  0.001940
# 0  90.829822 -32.390871      94  861103  0.028611
# 1  90.853320 -32.443048      94  861104  0.058099
# 3  91.005126 -32.421180      94  861106  0.125089
#
# DS19qcso 88.208631 -30.381382
#           RA      DEC  SEASON    SNID       SEP
# 0  88.208584 -30.3814      94  861109  0.000044
#
# DG19oahn 86.33527 -26.84768
#           RA        DEC  SEASON    SNID       SEP
# 0  86.335279 -26.847661      94  749902  0.000021
#
# ['DG19ukvo', 'DG19ootl']

# %%
fltobj = '/data/des41.a/data/desgw/alyssa_test2/FindGrowthCands/gw_workflow/ootl/se_856751/WS0094_856751_WS871-356_combined_z_47+fakeSN_filterObj.out'
f = open(fltobj, 'r')
objout = f.readlines()
f.close
# Out:
# <function close>

# %%
#bla = 'SNOBJID OBJECT_NUMBER MJD IFILT CCDNUM REJECT ERR RA DEC MAG MAGERR X_IMAGE Y_IMAGE A_IMAGE B_IMAGE FLUX FLUX_ERR GALFLUX  BACK BACKERR CHISQ NDOF XBAR YBAR NPOS0 NPOS1 NPOS2 NNEG0 NNEG1 NNEG2 VX VXERR VY VYERR SPROB PSFSIG FLAGS SEXFLUX_PSF SEXFLUXERR_PSF VETODIST VETORADIUS VETOTYPE SPRMOD SPRMODERR SNFAKE_ID'
#columns = bla.split(' ') ## need to remove the entry that is just a space
obs = pd.DataFrame(columns=columns)
for i ,line in enumerate(objout):
    if line.startswith('OBJ:'):
        l = line.split(' ')
        obs.loc[i] = l[1:]

# %%
ra, dec = 87.03556, -36.07611
for index, row in obs.iterrows():
    if float(row['RA'])-0.01 <= ra <= float(row['RA'])+0.01 and float(row['DEC'])-0.01 <= dec <= float(row['DEC'])+0.01:
        print row

# %% [markdown]
# # ootl has nothing in diff img. check y3 if there is a match (our temp too good??)

# %%
con = ea.connect('dessci')
# Out:
# Connecting to DB ** dessci ** ...
# *Important* Last time password change was 450 days ago
#  Please change it using the set_password command to get rid of this message

# %%
ra, dec = 87.03556, -36.07611
dl = 0.01
rahigh, ralow = ra+dl, ra-dl
dechigh, declow = dec+dl, dec-dl
query = ("SELECT d.COADD_OBJECT_ID, d.RA, d.DEC, d.DNF_ZMEAN_SOF,d.MAG_AUTO_G FROM Y3_GOLD_2_2 d" 
         " WHERE  RA <  "+str(rahigh)+" and RA > "+str(ralow)+" and DEC <  "+str(dechigh)+" "
         "and DEC >  "+str(declow)+" ")    
df = con.query_to_pandas(query)

for index, row in df.iterrows():
    ray3, decy3 = df['RA'], df['DEC']
    match = SkyCoord(ray3, decy3, unit='degree')
    cand = SkyCoord(ra, dec, unit='degree')
    sep = cand.separation(match)
    df['SEP']= sep

print df.sort_values('SEP')
# Out:
#     COADD_OBJECT_ID         RA        DEC  DNF_ZMEAN_SOF  MAG_AUTO_G       SEP
# 16        451563757  87.035553 -36.075959       0.070762   17.219896  0.000151
# 17        451564332  87.036530 -36.079332       0.494439   23.242533  0.003316
# 8         451564102  87.031170 -36.074575       0.678757   24.714775  0.003866
# 6         451564141  87.029885 -36.075620       0.238638   21.263889  0.004613
# 7         451564270  87.030363 -36.078156       0.375309   24.511766  0.004672
# 12        451563901  87.032708 -36.070700       0.876951   24.884338  0.005881
# 23        451564039  87.042425 -36.073328       0.804379   30.350279  0.006207
# 20        451563962  87.041058 -36.071773       0.840922   24.113667  0.006209
# 18        451563760  87.037580 -36.070090       0.053029   18.265495  0.006237
# 13        451563823  87.033958 -36.069904       0.709914   23.018606  0.006340
# 26        451564101  87.043579 -36.074536       0.730714   23.112627  0.006670
# ...

# %% [markdown]
# ### Templates used:
# cat WSTemplates/EXPNUM_LISTS/WS_diff.list
# 40 z 856751 802880 802873 802868 802865 802531 802529 802528 724438 724437 724433 724387 716950 716949 716945 716143 703596 617710 617709 617192 601558 601555 601553 516777 516776 516775 514807 502452 499551 494738 408049 407700 407697 405199 404838 404837 404827 393962 393961 387543

# %%
import subprocess

# %%
explist = '/data/des41.a/data/desgw/alyssa_test2/FindGrowthCands/gw_workflow/exposures.list'
temps = '802880 802873 802868 802865 802531 802529 802528 724438 724437 724433 724387 716950 716949 716945 716143 703596 617710 617709 617192 601558 601555 601553 516777 516776 516775 514807 502452 499551 494738 408049 407700 407697 405199 404838 404837 404827 393962 393961 387543'
temps = temps.split(' ')

# %%
for i, t in enumerate(temps):
    a= subprocess.check_output(['grep', t, explist])
    b = a.split(' ')
    b = [f for f in b if f != '']
    if b[0] == t:
        #df.loc[i] = b[0:8]
        print b[0:8]
# Out:
# ['802880', '20181213', '58466.100387', '89.116858', '-36.532416', 'z', '90.00', '2012B-0001']
# ['802873', '20181213', '58466.090683', '88.802250', '-34.503416', 'z', '90.00', '2012B-0001']
# ['802868', '20181213', '58466.083360', '86.732446', '-33.488916', 'z', '90.00', '2012B-0001']
# ['802865', '20181213', '58466.078912', '87.261271', '-37.546916', 'z', '90.00', '2012B-0001']
# ['802531', '20181212', '58465.067968', '86.983633', '-35.517916', 'z', '90.00', '2012B-0001']
# ['802529', '20181212', '58465.065215', '85.121071', '-36.532416', 'z', '90.00', '2012B-0001']
# ['802528', '20181212', '58465.063828', '84.907558', '-34.503416', 'z', '90.00', '2012B-0001']
# ['724438', '20180222', '58172.105891', '88.288246', '-37.513100', 'z', '90.00', '2012B-0001']
# ['724437', '20180222', '58172.104515', '87.984046', '-35.484100', 'z', '90.00', '2012B-0001']
# ['724387', '20180222', '58172.032971', '85.895654', '-34.469600', 'z', '90.00', '2012B-0001']
# ...

# %%
os.getcwd()
# Out:
# '/data/des41.a/data/alyssag/gw190510_paper/stamps'

# %%
Failedog700 = glob('/data/des71.b/data/desgw/dp700backup/20190510/856*/dp700/*_*/*.FAIL')
Totalog700 = glob('/data/des71.b/data/desgw/dp700backup/20190510/856*/dp700/*_*/*.tar.gz')

# %%
f = len(Failedog700)
t = len(Totalog700)
print f, t
print float(f)/float(t)
# Out:
# 1265 4543
# 0.278450363196

# %%
Failed800 = glob('/pnfs/des/persistent/gw/exp/20190728/*/dp800/*_*/*.FAIL')
Total800 = glob('/pnfs/des/persistent/gw/exp/20190728/*/dp800/*_*/*.tar.gz')

# %%
f = len(Failed800)
t = len(Total800)
print f, t
print float(f)/float(t)
# Out:
# 1159 4179
# 0.277339076334

# %%
Failed1000n1 = glob('/pnfs/des/persistent/gw/exp/20190814/*/dp1000/*_*/*.FAIL')
Total1000n1 = glob('/pnfs/des/persistent/gw/exp/20190814/*/dp1000/*_*/*.tar.gz')

# %%
f = len(Failed1000n1)
t = len(Total1000n1)
print f, t
print float(f)/float(t)
# Out:
# 305 2301
# 0.132551064754

# %% [markdown]
# # Make stamps from fits

# %%
# Gonna need these boys
from astropy.io import fits
from astropy import wcs
from astropy.coordinates import SkyCoord
from astropy.nddata import Cutout2D

# %%
## ra, dec of candidate -- center stamp around this
ra, dec = 87.03556, -36.07611

# %%
## load fits images
diffhdu = fits.open('/data/des41.a/data/desgw/alyssa_test2/FindGrowthCands/gw_workflow/ootl/se_856751/WS0094_856751_WS871-356_combined_z_47+fakeSN_diff_mh.fits')
searchhdu = fits.open('/pnfs/des/persistent/gw/exp/20190510/856751/D00856751_z_47_r4p7_immask.fits.fz')
temphdu = fits.open('/data/des41.a/data/desgw/alyssa_test2/FindGrowthCands/gw_workflow/ootl/se_856751/WSTemplate_856751_WS871-356_GWV1_z_47_coadd.fits')
## check to make sure you're using the right hdu, if there's more than one it should be 'SCI'
#print(hdu.info())
idxdiff, idxsrch, idxtemp = 0,1,0

datadiff = diffhdu[idxdiff].data
datasrch = searchhdu[idxsrch].data
datatemp = temphdu[idxtemp].data

## make sure ra dec are in astropy physical units
position = SkyCoord(ra,dec, unit="deg")

## you'll know you have the right hdu if this has 'CTYPE' not empty
wdiff = wcs.WCS(diffhdu[idxdiff].header)
wsrch = wcs.WCS(searchhdu[idxsrch].header)
wtemp = wcs.WCS(temphdu[idxtemp].header)

diffhdu.close()
searchhdu.close()
temphdu.close()

## make cut out centered at position, and size 49 x 49 pixels
cutoutdiff = Cutout2D(datadiff, position, (49, 49), wcs=wdiff)
cutoutsrch = Cutout2D(datasrch, position, (49, 49), wcs=wsrch)
cutouttemp = Cutout2D(datatemp, position, (49, 49), wcs=wtemp)

## show stamps side by side
fig, ax = plt.subplots(ncols=3, nrows=1, sharex=False, sharey=False, dpi=120)# figsize=(10,30))
ax[0].imshow(cutoutsrch.data, origin='lower',cmap='gray')
ax[1].imshow(cutouttemp.data, origin='lower',cmap='gray')
ax[2].imshow(cutoutdiff.data, origin='lower',cmap='gray')
ax[0].axis('off')
ax[1].axis('off')
ax[2].axis('off')
# Out:
# (-0.5, 48.5, -0.5, 48.5)

# %% [markdown]
# # Check failure rate

# %%
dp700fail = glob('/data/des71.b/data/desgw/dp700backup/20190510/85*/dp700/*_*/*.FAIL')
dp700tot = glob('/data/des71.b/data/desgw/dp700backup/20190510/85*/dp700/*_*/*.tar.gz')

# %%
dp1100fail = glob('/pnfs/des/persistent/gw/exp/20200*/9*/dp1100/i_*/*.FAIL')
dp1100tot = glob('/pnfs/des/persistent/gw/exp/20200*/9*/dp1100/i_*/*.tar.gz')

# %%
dp800fail = glob('/pnfs/des/persistent/gw/exp/2019072*/8*/dp801/*_*/*.FAIL')
dp800tot = glob('/pnfs/des/persistent/gw/exp/2019072*/8*/dp801/*_*/*.tar.gz')

# %%
dp1000fail = glob('/pnfs/des/persistent/gw/exp/201908*/8*/dp1000/*_*/*.FAIL')
dp1000tot = glob('/pnfs/des/persistent/gw/exp/201908*/8*/dp1000/*_*/*.tar.gz')

# %%
print "dp700", len(dp700fail), len(dp700tot), float(len(dp700fail))/float(len(dp700tot))
print
print "dp800", len(dp800fail), len(dp800tot), float(len(dp800fail))/float(len(dp800tot))
print
print "dp1000", len(dp1000fail), len(dp1000tot), float(len(dp1000fail))/float(len(dp1000tot))
print
print "dp1100", len(dp1100fail), len(dp1100tot), float(len(dp1100fail))/float(len(dp1100tot))
# Out:
# dp700 1265 4543 0.278450363196
#
# dp800 1447 6369 0.227194222013
#
# dp1000 3442 19599 0.175621205164
#
# dp1100 1360 6296 0.216010165184

# %%
dp700exps = glob('/data/des71.b/data/desgw/dp700backup/20190510/85*/dp700')
dp800exps = glob('/pnfs/des/persistent/gw/exp/2019072*/8*/dp801')
dp1000exps = glob('/pnfs/des/persistent/gw/exp/201908*/8*/dp1000')
dp1100exps = glob('/pnfs/des/persistent/gw/exp/20200*/9*/dp1100')

# %%
print len(dp700exps)
print len(dp800exps)
print len(dp1000exps)
print len(dp1100exps)
# Out:
# 79
# 108
# 349
# 108

# %%
# print dp700exps[0], dp700exps[-1]
# print dp800exps[0], dp800exps[-1]
# print dp1000exps[0], dp1000exps[-1]
# print dp1100exps[0], dp1100exps[-1]

# %%
full = open('/data/des41.a/data/desgw/O3FULL/AGManual-newexps-full700.list', 'r')
full700 = full.readlines()
full.close()

# %%
teff = []
for line in full700:
    t = [f for f in line.split(' ') if f != ''][-2]
    teff.append(float(t))
print sum(teff)/len(teff)
#print teff
# Out:
# 0.178875

# %%
full = open('/data/des41.a/data/desgw/O3FULL/800_full.list', 'r')
full800 = full.readlines()
full.close()

# %%
teff = []
for line in full800:
    t = [f for f in line.split(' ') if f != ''][9]
    teff.append(float(t))
print sum(teff)/len(teff)
#print teff
# Out:
# 0.449166666667

# %%
full = open('/data/des41.a/data/desgw/O3FULL/full20190814.list', 'r')
full1000 = full.readlines()
full.close()

teff = []
for line in full1000:
    t = [f for f in line.split(' ') if f != ''][9]
    if t == 'NaN':
        t = 0.
    teff.append(float(t))
print sum(teff)/len(teff)
#print teff
# Out:
# 0.205044776119

# %%
full = open('/data/des41.a/data/desgw/O3FULL/1100_full.list', 'r')
full1100 = full.readlines()
full.close()

teff = []
for line in full1100:
    t = [f for f in line.split(' ') if f != ''][9]
    if t == 'NaN':
        t = 0.
    teff.append(float(t))
print sum(teff)/len(teff)
#print teff
# Out:
# 1.15907407407

# %%
seasonfails = [dp700fail, dp800fail, dp1000fail, dp1100fail]
seasontots = [dp700tot, dp800tot, dp1000tot, dp1100tot]

for dpseason, dptot in zip(seasonfails, seasontots):
    step2, step3, step18, stepX = [],[],[],[]
    for f in dpseason:
        step = f.split('/')[-1].split('_')[0]
        if step == 'RUN18':
            step18.append(f)
        elif step == 'RUN02':
            step2.append(f)
        elif step == 'RUN03':
            step3.append(f)
        else:
            stepX.append(f)
    print "season:", dpseason[0].split('/')[-3]
    print "step2 ", len(step2), "%fail:", format(float(len(step2))/float(len(dpseason))*100,'.3f'), "%tot:", format(float(len(step2))/float(len(dptot))*100,'.3f')
    print "step3 ", len(step3), "%fail:",format(float(len(step3))/float(len(dpseason))*100, '.3f'), "%tot:", format(float(len(step3))/float(len(dptot))*100,'.3f')
    print "step18", len(step18),"%fail:", format(float(len(step18))/float(len(dpseason))*100, '.3f'), "%tot:", format(float(len(step18))/float(len(dptot))*100,'.3f')
    print "other ", len(stepX), "%fail:",format(float(len(stepX))/float(len(dpseason))*100, '.3f'), "%tot:", format(float(len(stepX))/float(len(dptot))*100,'.3f')
    print "total fail", len(dpseason)
    print "total tar", len(dptot)
    print
# Out:
# season: dp700
# step2  527 %fail: 41.660 %tot: 11.600
# step3  19 %fail: 1.502 %tot: 0.418
# step18 704 %fail: 55.652 %tot: 15.496
# other  15 %fail: 1.186 %tot: 0.330
# total fail 1265
# total tar 4543
#
# season: dp801
# step2  781 %fail: 53.974 %tot: 12.263
# step3  132 %fail: 9.122 %tot: 2.073
# step18 327 %fail: 22.598 %tot: 5.134
# other  207 %fail: 14.305 %tot: 3.250
# total fail 1447
# total tar 6369
#
# season: dp1000
# step2  76 %fail: 2.208 %tot: 0.388
# step3  320 %fail: 9.297 %tot: 1.633
# step18 2561 %fail: 74.404 %tot: 13.067
# other  485 %fail: 14.091 %tot: 2.475
# total fail 3442
# total tar 19599
#
# season: dp1100
# step2  980 %fail: 72.059 %tot: 15.565
# step3  58 %fail: 4.265 %tot: 0.921
# step18 104 %fail: 7.647 %tot: 1.652
# other  218 %fail: 16.029 %tot: 3.463
# total fail 1360
# total tar 6296

# %%
step2, step3, step18, stepX = [],[],[],[]
for f in dp700fail:
    step = f.split('/')[-1].split('_')[0]
    if step == 'RUN18':
        step18.append(f)
    elif step == 'RUN02':
        step2.append(f)
    elif step == 'RUN03':
        step3.append(f)
    else:
        stepX.append(f)
print "step2", len(step2)
print "step3", len(step3)
print "step18", len(step18)
print "other", len(stepX)
print "total fail", len(dp700fail)
print "total tar", len(dp700tot)
# Out:
# step2 527
# step3 19
# step18 704
# other 15
# total fail 1265
# total tar 4543
